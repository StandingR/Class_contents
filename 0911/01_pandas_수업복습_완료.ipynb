# %% [markdown]
# <a href="https://colab.research.google.com/github/StandingR/Class_contents/blob/main/0911/01_pandas_%EC%88%98%EC%97%85%EB%B3%B5%EC%8A%B5_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 판다스 기초
# https://doorbw.tistory.com/172

# %% [markdown]
# # Pandas
#
# Pandas는 파이썬에서 사용하는 데이터분석 라이브러리로, 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있게 되며 보다 안정적으로 대용량의 데이터들을 처리하는데 매우 편리한 도구 입니다.
#
#
#
# 먼저 pandas를 사용하기 위해서는 pandas를 설치한 이후에 아래와 같이 import를 해야 합니다.
#
#
#
# # import pandas as pd

# %% [markdown]
# # 1.Pandas 란?

# %%
# pandas 사용하기
import pandas as pd

# %% [markdown]
# #2.Pandas 자료구조
# Pandas에서는 기본적으로 정의되는 자료구조인 Series와 Data Frame을 사용합니다.
#
# 이 자료구조들은 빅 데이터 분석에 있어서 높은 수준의 성능을 보여준다.

# %% [markdown]
# ## 2-1 Series (1차원)
# 먼저, Serise 에 대해서 알아보자

# %%
# Series 정의하기
obj = pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
# Series의 값만 확인하기
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
# Series의 인덱스만 확인하기, 질문!  이해가 잘안됨
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Series의 자료형 확인하기
obj.dtypes
# Out:
# dtype('int64')

# %%
# 인덱스를 바꿀 수 있다.
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
# python의 dictionary 자료형을 Series data로 만들 수 있다.
# dictionary의 key가 Series의 index가 된다
sdata = {'Kim': 35000, 'Beomwoo': 67000, 'Joan': 12000, 'Choi': 4000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Kim        35000
# Beomwoo    67000
# Joan       12000
# Choi        4000
# dtype: int64

# %%
# index 변경
obj3.index = ['A', 'B', 'C', 'D']
obj3
# Out:
# A    35000
# B    67000
# C    12000
# D     4000
# dtype: int64

# %%
import pandas as pd
prices = [1000, 1010, 1020]
Series1 = pd.Series(prices) #Series 정의
Series1
# Out:
# 0    1000
# 1    1010
# 2    1020
# dtype: int64

# %%
dates = pd.date_range('20230101', periods = 3)
Series2 = pd.Series(prices, index = dates)
Series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1020
# Freq: D, dtype: int64

# %%
pd.date_range('2022-01-01', '2023-01-01', freq = 'M')
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2022-01-01', '2023-01-01', freq = 'MS')
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
Series2['2023-01-04'] = 1030
Series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1020
# 2023-01-04    1030
# Freq: D, dtype: int64

# %%
Series2[1:3]
# Out:
# 2023-01-02    1010
# 2023-01-03    1020
# Freq: D, dtype: int64

# %%
Series2[2]
# Out:
# 1020

# %%
Series2['2023-01-03']
# Out:
# 1020

# %%
Series2[2] = 1080
Series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1080
# 2023-01-04    1030
# Freq: D, dtype: int64

# %% [markdown]
# ## DataFrame (2차원)
#
# ### 1. DataFrame은 2차원 테이블 데이터 구조를 가지는 자료형이다.그리고 Series와 함께 pandas의 주요 데이터 유형 중 하나이다.
#
# - Series 객체를 딕셔너리처럼 모아둔 컨테이너(contaier)라고 봐도 된다.
# - Series 객체를 모아둔 자료구조라 생각하면 이해하기 편하다.
# - 스프레트시트나 SQL 테이블이라고 생각해도 무방하다.
#
# ### DataFrame 의 특징
# pandas 의 Data Frame은 몇 가지 특징을 가지는데 다음과 같다.
#
# - DataFrame의 크기가 변경이 가능하다.
# - 행 혹은 열이 같지 않은(heterogeneous)데이터로 표를 형성 시킬수 있다.
# - 산술 연산을 수행할 시 Series와 마찬가지로 행과 열 레이블(label)을 정렬 시킨 후 산술연산을 진행한다.
# - 각 열 마다 다른 자료형(dtype)을 사용하는 것이 가능하다.

# %%
# DataFrame 의 단순한 생성법
# 주의! data에 입력되는 변수가 어떤 자료형을 가지느냐에 따라 DataFrame() 함수의 결과는 달라지게 되므로 주의하자.

DataFrame = pandas.DataFrame(data,index=index값, columns = columns의 값)

# %% [markdown]
# ## DATA
#
# - 여기서 data는 여러가지 자료형을 포함할 수 있다.
# Series와 마찬가지로 DataFrame은 많은 다른 종류의 입력데이터를 사용한다.
# 여기서 data는 여러가지 자료형을 포함할 수 있다.
#
# Series와 마찬가지로 DataFrame은 많은 다른 종류의 입력데이터를 사용한다.
#
#   ○ 딕셔너리(dictionary, dict)의 값(value)에 다음의 자료형을 포함할 때
#
#     ▷ 1차원 ndarray
#
#     ▷ 리스트(list)
#
#     ▷ Series
#
#     ▷ 딕셔너리
#
#   ○ 하나의 Series
#
#   ○ 2차원 numpy.ndarray, 리스트의 리스트
#
#   ○ 구조체(structured) ndarray 혹은 record ndarray
#
#   ○ 또다른 DataFrame
#
#   index
#
# 입력된 index는 행의 레이블의 리스트를 입력받는다.
#
#
#
# columns
#
# 입력된 columns는 열의 레이블의 리스트를 입력받는다.

# %%
# Data Frame 정의
# 이전에 DataFrame에 들어갈 데이터를 정의해주어야 하는데,
#이는 python의 dictionary 또는 numpy 의 array로 정의할 수 있다. -> 정리 필요

data = {'name' : ['Beomwoo','Beomwoo','Beomwoo','Kim','park'], # dictionary의 형태
'year':[2013,2014,2015,2016,2015],
'point' : [1.5,1.7,3.6,2.4,2.9]}

df = pd.DataFrame(data)
df
# Out:
#       name  year  point
# 0  Beomwoo  2013    1.5
# 1  Beomwoo  2014    1.7
# 2  Beomwoo  2015    3.6
# 3      Kim  2016    2.4
# 4     park  2015    2.9

# %%
# 행과 열의 구조를 가진 데잍가 생긴다. # object는 객체를 의미

# %%
# 행 방향의 index
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# 열 방향의 index
df.columns
# Out:
# Index(['name', 'year', 'point'], dtype='object')

# %%
# 값 얻기
df.values
# Out:
# array([['Beomwoo', 2013, 1.5],
#        ['Beomwoo', 2014, 1.7],
#        ['Beomwoo', 2015, 3.6],
#        ['Kim', 2016, 2.4],
#        ['park', 2015, 2.9]], dtype=object)

# %%
# 각 인덱스에 대한 이름 설정하기
df.index.name = 'num'
df.columns.name = 'Info'
df
# Out:
# Info     name  year  point
# num
# 0     Beomwoo  2013    1.5
# 1     Beomwoo  2014    1.7
# 2     Beomwoo  2015    3.6
# 3         Kim  2016    2.4
# 4        park  2015    2.9

# %%
# DataFrame을 만들면서 columns와 index를 설정할 수 있다. 튜플 이용

df2 = pd.DataFrame(data, columns=['year','name','points','penalty',],
                   index = ['one','two','three','four','five'])
df
# Out:
# Info     name  year  point
# num
# 0     Beomwoo  2013    1.5
# 1     Beomwoo  2014    1.7
# 2     Beomwoo  2015    3.6
# 3         Kim  2016    2.4
# 4        park  2015    2.9

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
# describe() 함수는 DataFrame의 계산 가능한 값들에 대한 다양한 계산 값을 보여준다.
df.describe()
# Out:
# Info          year     point
# count     5.000000  5.000000
# mean   2014.600000  2.420000
# std       1.140175  0.864292
# min    2013.000000  1.500000
# 25%    2014.000000  1.700000
# 50%    2015.000000  2.400000
# 75%    2015.000000  2.900000
# max    2016.000000  3.600000

# %%
# DataFrame에서 행을 선택하고 조작하기
# pandas에서는 무수히 많은 행을 인덱싱하는 방법이 있다.

# %%
# 원래의 데이터 베이스
df
# Out:
# Info     name  year  point
# num
# 0     Beomwoo  2013    1.5
# 1     Beomwoo  2014    1.7
# 2     Beomwoo  2015    3.6
# 3         Kim  2016    2.4
# 4        park  2015    2.9

# %%
# 0번째 부터 2(3-1) 번째까지 가져온다.
# 뒤에 써준 숫자번째의 행은 뺀다.
df[0:3]
# Out:
# Info     name  year  point
# num
# 0     Beomwoo  2013    1.5
# 1     Beomwoo  2014    1.7
# 2     Beomwoo  2015    3.6

# %%
# 아래 방법을 권장한다.
# .loc 또는 .iloc 함수를 사용하는 방법.
df.loc[1,'name'] # 반환 형태는 Series loc 함수는 인덱스, 컬럼순으로 값을 가져온다. loc 함수는 index, columns순으로 가져온다.
# Out:
# 'Beomwoo'

# %%
# 인덱싱 해서 가져오기
df.loc['info':'point']
# Out:
# Empty DataFrame
# Columns: [name, year, point]
# Index: []

# %%
# .iloc 사용 : index 번호를 사용한다.
df.iloc[2] #2번쨰 행을 가져온다.
# Out:
# Info
# name     Beomwoo
# year        2015
# point        3.6
# Name: 2, dtype: object

# %%
df.iloc[]

# %%
prices = {
    'SK텔레콤' : [44000, 44500, 45000],
    '삼성전자' : [70100, 70200, 70300],
    'LG전자' : [85000, 85500, 86000]
}
df1 = pd.DataFrame(prices, index = [1,2,3])
df1
# Out:
#    SK텔레콤   삼성전자   LG전자
# 1  44000  70100  85000
# 2  44500  70200  85500
# 3  45000  70300  86000

# %%
df1.loc[1,'삼성전자']
# Out:
# 70100

# %%
df2 = pd.DataFrame(prices, index = dates)
df2
# Out:
#             SK텔레콤   삼성전자   LG전자
# 2023-01-01  44000  70100  85000
# 2023-01-02  44500  70200  85500
# 2023-01-03  45000  70300  86000

# %% [markdown]
# ### 데이터 선택
# - loc : index, column으로 데이터를 가져온다.
# - iloc : 데이터 순서로 데이터를 가져온다.(즉 데이터들이 위치한 순서대로)

# %%
df2.iloc[0]
# Out:
# SK텔레콤    44000
# 삼성전자     70100
# LG전자     85000
# Name: 2023-01-01 00:00:00, dtype: int64

# %%
df2.iloc[:,0]
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2.iloc[0,0]
# Out:
# 44000

# %%
df2.loc['2023-01-02']
# Out:
# SK텔레콤    44500
# 삼성전자     70200
# LG전자     85500
# Name: 2023-01-02 00:00:00, dtype: int64

# %%
df2.loc[:,'SK텔레콤']
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2['SK텔레콤']
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2.SK텔레콤
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2['POSCO'] = [450000, 455000, 460000]
df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO
# 2023-01-01  44000  70100  85000  450000
# 2023-01-02  44500  70200  85500  455000
# 2023-01-03  45000  70300  86000  460000

# %% [markdown]
# ### [실습]
# Q1. 2023년 1월 2일 ~ 2023 1월 3일 까지의 '삼성전자', 'LG전자' 데이터를 가져와주세요.

# %%
df2.iloc[1:3,1:3]
# Out:
#              삼성전자   LG전자
# 2023-01-02  70200  85500
# 2023-01-03  70300  86000

# %%
df2.iloc[1:3,[1,2]]
# Out:
#              삼성전자   LG전자
# 2023-01-02  70200  85500
# 2023-01-03  70300  86000

# %%
df2.loc['2023-01-02':,'삼성전자':'LG전자']
# Out:
#              삼성전자   LG전자
# 2023-01-02  70200  85500
# 2023-01-03  70300  86000

# %% [markdown]
# Q2. 데이터 70200원 가져오기 (iloc, loc 각각 활용)

# %%
df2.iloc[1,1]
# Out:
# 70200

# %%
df2.loc['2023-01-02','삼성전자']
# Out:
# 70200

# %% [markdown]
# ### 데이터프레임 확장
# - concat : 그냥 가져다 붙이는 거
# - merge : 공통된 칼럼이나 인덱스가 있는가 있는 경우

# %%
s1 = pd.Series([500000, 500500, 501000]
               , index = dates, name = 'LG화학')

# %%
concat_df2 = pd.concat([df2, s1], axis = 1)
concat_df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO    LG화학
# 2023-01-01  44000  70100  85000  450000  500000
# 2023-01-02  44500  70200  85500  455000  500500
# 2023-01-03  45000  70300  86000  460000  501000

# %%
concat_df2['LG화학_add_500'] = concat_df2['LG화학'] + 500
concat_df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO    LG화학  LG화학_add_500
# 2023-01-01  44000  70100  85000  450000  500000        500500
# 2023-01-02  44500  70200  85500  455000  500500        501000
# 2023-01-03  45000  70300  86000  460000  501000        501500

# %%
concat_df2.loc['2023-01-06',:] = [44000, 70100, 85000, 455000, 505000, 505500]
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0

# %%
concat_df2.loc['2023-01-05',:] = concat_df2.loc['2023-01-06',:] - 100
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0

# %% [markdown]
# ### 데이터 정렬

# %%
concat_df2.sort_index()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0

# %%
concat_df2.sort_values(by = '삼성전자')
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0

# %%
concat_df2.sort_values(by = '삼성전자', ascending = False)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0

# %% [markdown]
# ### 데이터 삭제

# %%
concat_df2.drop('2023-01-03', inplace = True)

# %%
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0

# %%
concat_df2.drop('LG화학_add_500', axis = 1)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0

# %%
concat_df2.drop(['LG화학','LG화학_add_500'], axis = 1)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO
# 2023-01-01  44000.0  70100.0  85000.0  450000.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0

# %% [markdown]
# ### 데이터프레임 다루기

# %%
concat_df2['sum'] = concat_df2.sum(axis = 1)
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  504900.0      505400.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-06  1664600.0
# 2023-01-05  1664000.0

# %%
concat_df2.min(axis = 0)
# Out:
# SK텔레콤             43900.0
# 삼성전자              70000.0
# LG전자              84900.0
# POSCO            450000.0
# LG화학             500000.0
# LG화학_add_500     500500.0
# sum             1649600.0
# dtype: float64

# %%
concat_df2.describe()
# Out:
#              SK텔레콤          삼성전자         LG전자         POSCO           LG화학  \
# count      4.00000      4.000000      4.00000       4.00000       4.000000
# mean   44100.00000  70100.000000  85100.00000  453725.00000  502600.000000
# std      270.80128     81.649658    270.80128    2483.78072    2721.519184
# min    43900.00000  70000.000000  84900.00000  450000.00000  500000.000000
# 25%    43975.00000  70075.000000  84975.00000  453675.00000  500375.000000
# 50%    44000.00000  70100.000000  85000.00000  454950.00000  502700.000000
# 75%    44125.00000  70125.000000  85125.00000  455000.00000  504925.000000
# max    44500.00000  70200.000000  85500.00000  455000.00000  505000.000000
#
#         LG화학_add_500           sum
# count       4.000000  4.000000e+00
# mean   503100.000000  1.658725e+06
# std      2721.519184  7.064170e+03
# min    500500.000000  1.649600e+06
# 25%    500875.000000  1.654925e+06
# 50%    503200.000000  1.660350e+06
# 75%    505425.000000  1.664150e+06
# ...

# %% [markdown]
# ### 결측치 처리
# - 제거 : dropna
# - 대체 : fillna, interpolate

# %%
concat_df2.sort_index(inplace = True)

# %%
import numpy as np
concat_df2.loc['2023-01-05',"LG전자":'LG화학'] = np.NaN
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0
# 2023-01-06  1664600.0

# %%
concat_df2.dropna(axis = 1)
# Out:
#               SK텔레콤     삼성전자  LG화학_add_500        sum
# 2023-01-01  44000.0  70100.0      500500.0  1649600.0
# 2023-01-02  44500.0  70200.0      501000.0  1656700.0
# 2023-01-05  43900.0  70000.0      505400.0  1664000.0
# 2023-01-06  44000.0  70100.0      505500.0  1664600.0

# %%
concat_df2.fillna(method = 'bfill')
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0  85000.0  455000.0  505000.0      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0
# 2023-01-06  1664600.0

# %%
concat_df2.interpolate()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0  85250.0  455000.0  502750.0      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0
# 2023-01-06  1664600.0

# %% [markdown]
# ### 중복제거

# %%
concat_df3 = concat_df2.copy()
concat_df4 = pd.concat([concat_df2, concat_df3])
concat_df4
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0
# 2023-01-06  1664600.0
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0
# 2023-01-06  1664600.0

# %%
concat_df4.drop_duplicates()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  505000.0      505500.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0
# 2023-01-06  1664600.0

# %%
concat_df2.loc['2023-01-03',:] = concat_df2.loc['2023-01-06',:].copy()
concat_df2.sort_index(inplace = True)

# %%
# 삼성전자의 중복만 제거하여 데이터프레임 형태로 출력

concat_df3.drop_duplicates(['삼성전자'])
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0

# %%
concat_df3.drop_duplicates(['삼성전자','삼성전자'])
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0

# %%
idx = concat_df2['삼성전자'].drop_duplicates().index
concat_df2.loc[idx, :]
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      505400.0
#
#                   sum
# 2023-01-01  1649600.0
# 2023-01-02  1656700.0
# 2023-01-05  1664000.0

# %%
dates = pd.date_range('2022-01-01', periods = 12)
Series2 = pd.Series(prices, index = dates)
Series2
# Out:
# 2022-01-01    NaN
# 2022-01-02    NaN
# 2022-01-03    NaN
# 2022-01-04    NaN
# 2022-01-05    NaN
# 2022-01-06    NaN
# 2022-01-07    NaN
# 2022-01-08    NaN
# 2022-01-09    NaN
# 2022-01-10    NaN
# 2022-01-11    NaN
# 2022-01-12    NaN
# Freq: D, dtype: object

# %%
dates = {
    '2022-01-01' : [44000, 44500, 45000],
    '삼성전자' : [70100, 70200, 70300],
    'LG전자' : [85000, 85500, 86000]
}
df1 = pd.DataFrame(prices, index = [1,2,3])
df1
